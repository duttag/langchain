# %% [markdown]
# ## Agents
#
# Agents combine language models with tools to create systems that can reason about tasks, decide which tools to use, and iteratively work towards solutions.
# create_agent provides a production-ready agent implementation.
# An LLM Agent runs tools in a loop to achieve a goal. An agent runs until a stop condition is met - i.e., when the model emits a final output or an iteration limit is reached.
#
# <img src="agent.png" width="200">

# %%
import os
from langchain_openrouter import ChatOpenRouter

os.environ["OPENROUTER_API_KEY"] = "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"

model = ChatOpenRouter(model="auto")
response = model.invoke("Why do parrots talk?")
print(response)
# Out:
# content=" Parrots have the ability to mimic human speech and other sounds due to a complex syrinx, which is the avian equivalent of the human larynx. The exact reason why parrots talk is not fully understood, but there are several theories.\n\nOne theory suggests that talking helps parrots communicate with each other and strengthen social bonds. Parrots are social animals and living in flocks provides them with protection and access to food. Talking may help them identify individuals within their flock and maintain social order.\n\nAnother theory is that talking helps parrots attract mates. By mimicking the sounds of their environment, parrots can make themselves more noticeable and attractive to potential mates.\n\nAdditionally, some researchers believe that talking may serve a functional purpose, such as warning other parrots of danger or signaling the location of food sources.\n\nIt's also important to note that not all parrots talk, and the ability to mimic human speech is not necessary for survival. Talking is a learned behavior, and parrots that are exposed to human speech and other sounds are more likely to develop this ability." additional_kwargs={} response_metadata={'model_name': 'mistralai/mistral-7b-instruct-v0.1', 'id': 'gen-1778557007-4hLu91fvqws9rcmhkR18', 'created': 1778557007, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--019e1a42-33ad-7151-8627-8ffdfdfda325-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 245, 'total_tokens': 260, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}
