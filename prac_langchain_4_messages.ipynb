# %%
import os
from langchain_openrouter import ChatOpenRouter

os.environ["OPENROUTER_API_KEY"] = "sk-xr-w2-exxxxxxxx"

model = ChatOpenRouter(model="openai/gpt-4o-mini", # "auto" can be an option
                       max_tokens=200,
                       temperature=0.7,)

response = model.invoke("Hi, Which model are you using?")
print(response)
# Out:
# content="I'm based on OpenAI's GPT-3 model. How can I assist you today?" additional_kwargs={} response_metadata={'model_name': 'openai/gpt-4o-mini', 'id': 'gen-1778580513-OZIyXVL0A7wRr2efCyXj', 'created': 1778580513, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'system_fingerprint': 'fp_eb37e061ec'} id='lc_run--019e1ba8-e0ff-7ed2-b69c-e11111296e97-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 19, 'total_tokens': 34, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}

# %%
from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather at a location."""
    return f"It's sunny in {location}."

model_with_tools = model.bind_tools([get_weather])
response = model_with_tools.invoke("What's the weather in Paris?")

for tool_call in response.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
    print(f"ID: {tool_call['id']}")

response.usage_metadata
# Out:
# Tool: get_weather
# Args: {'location': 'Paris'}
# ID: call_xTVUaRndqSIqjyvXnbmfrPvd
# {'input_tokens': 50,
#  'output_tokens': 14,
#  'total_tokens': 64,
#  'input_token_details': {'cache_read': 0, 'cache_creation': 0},
#  'output_token_details': {'reasoning': 0}}

# %%
response = model.invoke("Hello!")
response.usage_metadata
# Out:
# {'input_tokens': 9,
#  'output_tokens': 10,
#  'total_tokens': 19,
#  'input_token_details': {'cache_read': 0, 'cache_creation': 0},
#  'output_token_details': {'reasoning': 0}}

# %%
chunks = []
full_message = None
for chunk in model.stream("Hi"):
    chunks.append(chunk)
    print(chunk.text)
    full_message = chunk if full_message is None else full_message + chunk

print("Full message:", full_message.text)   
print(chunks)
# Out:
# Hello
# !
#  How
#  can
#  I
#  assist
#  you
#  today
# ?
#
#
#
# Full message: Hello! How can I assist you today?
# [AIMessageChunk(content='Hello', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content='!', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' How', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' assist', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content=' today', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content='?', additional_kwargs={}, response_metadata={'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_5feb5fe6c2', 'id': 'gen-1778580674-jPBGESWaCrw3IZdsul4j', 'created': 1778580674, 'object': 'chat.completion.chunk', 'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[]), AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_5feb5fe6c2', 'id': 'gen-1778580674-jPBGESWaCrw3IZdsul4j', 'created': 1778580674, 'object': 'chat.completion.chunk', 'model_provider': 'openrouter'}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}, tool_call_chunks=[]), AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019e1bab-5658-7261-bc2d-9005e3495d61', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')]

# %%
# ToolMessage

from langchain.messages import AIMessage
from langchain.messages import HumanMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result
print(response.content)
print(response)
# Out:
# The weather in San Francisco is sunny with a temperature of 72°F.
# content='The weather in San Francisco is sunny with a temperature of 72°F.' additional_kwargs={} response_metadata={'model_name': 'openai/gpt-4o-mini', 'id': 'gen-1778581010-iZK76MrizfH1dsBslxyU', 'created': 1778581010, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'system_fingerprint': 'fp_eb37e061ec'} id='lc_run--019e1bb0-799b-72e1-a3a4-517b3763a51d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 16, 'total_tokens': 58, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}
